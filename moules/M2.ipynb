# %% [markdown]
# ## DATA VISUALIZATION AND DATA ANALYSIS

# %%
# Import the necessary libraries.
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('weather_data.csv')
df.head()
# Out:
#         City  Temperature_Celsius  Wind_Speed_ms  Latitude  Longitude  \
# 0      Paris                10.46           2.06   48.8534     2.3488
# 1      Dubai                29.32           3.09   25.2582    55.3047
# 2     Madrid                 9.97           3.60   40.4165    -3.7026
# 3      Tokyo                21.58           2.06   35.6895   139.6917
# 4  Amsterdam                 8.00           3.58   52.3740     4.8897
#
#      Description               Country
# 0      clear sky                France
# 1      clear sky  United Arab Emirates
# 2      clear sky                 Spain
# 3  broken clouds                 Japan
# 4      clear sky           Netherlands

# %%
# Transform the columns value(ex: int to str, str to int) for classification purpose.
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

var = ['City','Description','Country']
  
for i in var:
    df[i] = le.fit_transform(df[i]).astype(int)

# %%
# Check the top5 values
df.head()
# Out:
#    City  Temperature_Celsius  Wind_Speed_ms  Latitude  Longitude  Description  \
# 0    61                10.46           2.06   48.8534     2.3488            1
# 1    18                29.32           3.09   25.2582    55.3047            1
# 2    44                 9.97           3.60   40.4165    -3.7026            1
# 3    88                21.58           2.06   35.6895   139.6917            0
# 4     1                 8.00           3.58   52.3740     4.8897            1
#
#    Country
# 0       13
# 1       43
# 2       37
# 3       22
# 4       27

# %%
# Remove the null value
df = df.dropna()

# %%
# Remove the duplicate values
df=df.drop_duplicates()

# %%
# Check the data is balanced or imbalanced so that's why we use Countplot.
plt.figure(figsize=(12,7))
sns.countplot(x='Description',data=df)
# Out:
# <Axes: xlabel='Description', ylabel='count'>

# %%
# Plot a Histogram
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
plt.hist(df["Temperature_Celsius"],color='red')

plt.subplot(1,2,2)
plt.hist(df["Longitude"],color='blue')
# Out:
# (array([ 1.,  7., 13.,  3.,  5., 29., 14.,  4., 14., 10.]),
#  array([-157.8583 , -126.95174,  -96.04518,  -65.13862,  -34.23206,
#           -3.3255 ,   27.58106,   58.48762,   89.39418,  120.30074,
#          151.2073 ]),
#  <BarContainer object of 10 artists>)

# %%
# Check how many columns are in datasets
df.columns
# Out:
# Index(['City', 'Temperature_Celsius', 'Wind_Speed_ms', 'Latitude', 'Longitude',
#        'Description', 'Country'],
#       dtype='object')

# %%
# Plot a Histogram.
df.hist(figsize=(15,55), color='green')
plt.show()

# %%
# Plot a Histogram
df["Latitude"].hist(figsize=(10,5),color='yellow',bins=25)
# Out:
# <Axes: >

# %%
# Check the outliers our datasets.
plt.boxplot(df["Longitude"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2313aebd070>,
#   <matplotlib.lines.Line2D at 0x2313aebd310>],
#  'caps': [<matplotlib.lines.Line2D at 0x2313aebd5b0>,
#   <matplotlib.lines.Line2D at 0x2313aebd850>],
#  'boxes': [<matplotlib.lines.Line2D at 0x2313aeaad90>],
#  'medians': [<matplotlib.lines.Line2D at 0x2313aebdaf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2313aebdd90>],
#  'means': []}

# %%
# Plot a density plot
df["Description"].plot(kind='density')
# Out:
# <Axes: ylabel='Density'>

# %%
# Plot a distance plot
sns.displot(df["Country"], color='purple') 
# barplot, boxenplot, boxplot, countplot, displot, distplot, ecdfplot, histplot, kdeplot, pointplot, violinplot, stripplot

# %%
# Plot a distance plot.
sns.displot(df["Country"], color='coral') # residplot, scatterplot

# %%
# Plot a head map for co relationships for each columns.
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(df.corr(),annot = True, fmt='0.2%',cmap = 'autumn',ax=ax)
# Out:
# <Axes: >

# %%
# Plot a Piechart 
def plot(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(9,9), autopct='%1.2f%%', fontsize = 10)
    ax.set_title(variable + ' \n', fontsize = 10)
    return np.round(dataframe_pie/df.shape[0]*100,2)

plot(df, 'Description')
# Out:
# Description
# 1     40.0
# 10    15.0
# 0     13.0
# 9     10.0
# 2      9.0
# 6      6.0
# 11     1.0
# 7      1.0
# 8      1.0
# 5      1.0
# 3      1.0
# 4      1.0
# 12     1.0
# Name: count, dtype: float64
